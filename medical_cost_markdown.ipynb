# %% [markdown]
# # MEDICAL COST

# %% [markdown]
# #### GEREKLİ KÜTÜPHANELERİN EKLENMESİ

# %% [markdown]
# * Önce gerekli kütüphaneleri "import" ettik indirilmesi gereken dosyaları "pip install" ile indirdik.

# %% [markdown]
# #### Datasetin indirilmesi

# %% [markdown]
# * "insurance.csv" dosyasını dosyama yükledim

# %% [markdown]
# #### Keşifsel Veri Analizi

# %% [markdown]
# * fonksiyonel olarak göstermek ve hepsini bir arada analiz etmek için "check_df" fonksiyon oluşturduk

# %% [markdown]
# #### Kategorik ve Numerik Değişkenleri gözlemledik

# %% [markdown]
# * Kategorik : sex,smoker,region
# * Numerik fakat Cardinal : children
# * Categorik fakat Cardinal : bmi,charges
# * Numerik : age,bmi,children,charges
#
# * en son bunları fonksiyonlaştırdık ve görselleştirdik

# %% [markdown]
# #### Target Değişkenini Analiz Etme

# %% [markdown]
# * hedef değişkenle diğer değişkenleri kıyasladık

# %% [markdown]
# #### Smoker ve Charges arasındaki ilişkiyi inceleyelim

# %% [markdown]
# ![e9dfe4ea-aada-4790-9300-affa590bb160.png](attachment:e9dfe4ea-aada-4790-9300-affa590bb160.png)

# %% [markdown]
# ![113d8659-ee53-4268-a0a1-713038178a64.png](attachment:113d8659-ee53-4268-a0a1-713038178a64.png)

# %% [markdown]
# ![f647c78b-4879-4adb-86eb-7a4a5bb2493c.png](attachment:f647c78b-4879-4adb-86eb-7a4a5bb2493c.png)

# %% [markdown]
# #### Smoker ile Region arasındaki ilişkiyi inceleyelim

# %% [markdown]
# * ikisi arasındaki ilişkiyi inceleyip görselleştirmek için "label encoding" yaptık

# %% [markdown]
# ![816d3789-453f-4836-a3d9-39a38c7cec77.png](attachment:816d3789-453f-4836-a3d9-39a38c7cec77.png)

# %% [markdown]
# ![9a1395f8-1710-4e27-af86-ff682e105853.png](attachment:9a1395f8-1710-4e27-af86-ff682e105853.png)

# %% [markdown]
# ![9b7de98c-f77c-4bdc-94eb-82e47a4eaa64.png](attachment:9b7de98c-f77c-4bdc-94eb-82e47a4eaa64.png)

# %% [markdown]
# #### Bmi ile Sex arasındaki ilişkiyi inceleyelim

# %% [markdown]
# ![e897d19c-4116-4a6b-be1a-7ba065f41eed.png](attachment:e897d19c-4116-4a6b-be1a-7ba065f41eed.png)

# %% [markdown]
# ![bd16b180-e26c-4913-90f7-e753308c4174.png](attachment:bd16b180-e26c-4913-90f7-e753308c4174.png)

# %% [markdown]
# #### En çok Children'a sahip Region'ı bulunuz

# %% [markdown]
# ![d92d823f-eda6-4fe1-9522-d3e2d31ed147.png](attachment:d92d823f-eda6-4fe1-9522-d3e2d31ed147.png)

# %% [markdown]
# #### Kolerasyon Analizi

# %% [markdown]
# * kolerasyon : değişkenlerin birbiriyle ilişkisini ifade eden bir ölçümdür -1 ile 1 arasındadır
# * 1 : pozitif korelasyon -1 : negatif korelasyon
# * 1 e yaklaştıkça ilişki şiddeti kuvvetli , -1 e yaklaştıkça ilişki şiddeti azdır.
# * 0 civarında ise "kolerasyon yoktur!!!"

# %% [markdown]
# ![e308ff2f-9416-4f9d-896d-ac8872457a66.png](attachment:e308ff2f-9416-4f9d-896d-ac8872457a66.png)

# %% [markdown]
# #### Age ile Bmi arasındaki ilişkiyi inceleyiniz

# %% [markdown]
# ![48c52225-6a12-49cf-b54f-9ad398c5762b.png](attachment:48c52225-6a12-49cf-b54f-9ad398c5762b.png)

# %% [markdown]
# ![a73481b9-087a-4a09-852b-660083b43b60.png](attachment:a73481b9-087a-4a09-852b-660083b43b60.png)

# %% [markdown]
# #### Bmi ile Children arasındaki ilişkiyi inceleyelim

# %% [markdown]
# ![6160dae9-3b67-44cb-b342-d8e1fa788eb9.png](attachment:6160dae9-3b67-44cb-b342-d8e1fa788eb9.png)

# %% [markdown]
# #### Bmi ile Charges arasındaki ilişkiyi inceleyelim

# %% [markdown]
# ![ee194bb8-f6b6-4b1e-bec2-faa56e9ad967.png](attachment:ee194bb8-f6b6-4b1e-bec2-faa56e9ad967.png)

# %% [markdown]
# #### Region , Smoker ve Bmi arasındaki ilişiyi bar plot ile inceleyelim

# %% [markdown]
# ![9471e49e-d128-4c63-9752-1409cfb29b11.png](attachment:9471e49e-d128-4c63-9752-1409cfb29b11.png)

# %% [markdown]
# #### Veri Ön İşleme Yapılması

# %% [markdown]
# * Outliersları belirledik ve bu aralık dışında kalanlar aykırı gözlemlerdir

# %% [markdown]
# Outliers değerleri silemeyiz belki de gerçekten "charges" yani masrafların az olduğu ücretler olabilir o yüzden silmememiz gerekiyor sadece tespit ettik sonrasında "Standart Scaler" uygulayabiliriz.

# %% [markdown]
# #### One Hot Encoding :
# * sınıflar arası fark yokken varmış gibi olacaktır
#
# * sınıfları değişkenlere dönüştürme
#
# * ilk sınıf drop edilirse problem yaşanmaz

# %% [markdown]
# #### Standart Scaler

# %% [markdown]
# * Bmi, charges, age ile standartlaştırarak normalize hale getiriyoruz

# %% [markdown]
# #### X_train,y_train,X_test,y_test olarak veri seti bölüştürülür

# %% [markdown]
# #### Model Seçme ve Hiper-Parametre Optimizasyonu

# %% [markdown]
# ![c1210ab3-73c0-4b7a-b012-c557bb66076f.png](attachment:c1210ab3-73c0-4b7a-b012-c557bb66076f.png)

# %% [markdown]
# * Linar Regression ve Random Forest Regression modellerini seçtim ve karşılaştırdım sonuç olarak
# Random Forest daha başarılı çıktı

# %% [markdown]
# #### Modeli Değerlendirme

# %% [markdown]
# * 3 farklı şekilde modelimi değerlendirdim

# %% [markdown]
# #### Kneighbors Regressor
# * Mean absolute error = 0.34
# * Mean squared error = 0.33
# * Median absolute error = 0.13
# * Explain variance score = 0.69
# * R2 score = 0.69

# %% [markdown]
# #### Random ForestRegressor
# * Mean absolute error = 0.2
# * Mean squared error = 0.14
# * Median absolute error = 0.08
# * Explain variance score = 0.87
# * R2 score = 0.87

# %% [markdown]
# #### Linear Regression
# * Mean absolute error = 0.35
# * Mean squared error = 0.23
# * Median absolute error = 0.22
# * Explain variance score = 0.78
# * R2 score = 0.78
